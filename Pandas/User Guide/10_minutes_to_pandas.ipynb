# %% [markdown]
# # 10 Minutes to Padas
#
# This is a short introduction to pandas.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Data Structures in Pandas
#
# Pandas provides two types of classes for handling data:
#
# `Series`: **a one-dimensional labeled array holding data of any type**
# such as integers, strings, Python objects etc.
#
# `DataFrame`: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %% [markdown]
# ## Object Creation
#
# Creating a `Series` by passing a list of values, letting pandas create a default `RangeIndex`.

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a `DataFrame` by passing a Numpy array with a datatime index using `data_range()` and labeled columns:

# %%
dates = pd.date_range("20130101", periods = 6)
dates

# %%
df = pd.DataFrame(np.random.rand(6,4), index = dates, columns = list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.031456  0.606786  0.489153  0.608915
# 2013-01-02  0.437252  0.193781  0.698477  0.497230
# 2013-01-03  0.560852  0.689439  0.364026  0.950522
# 2013-01-04  0.430390  0.752366  0.571990  0.086978
# 2013-01-05  0.369941  0.326520  0.587998  0.773797
# 2013-01-06  0.548520  0.519458  0.591992  0.354832

# %% [markdown]
# Creating a `DataFrame` by passing a dictionary of objects where the keys are the column labels and the values are the column values.

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# The columns of the resulting DataFrame have different dtypes:

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ## Viewing Data
#
# Use `DataFrame.head()` and `DataFrame.tail()` to view the top and bottom rows of the frame respectively:

# %%
df.head(3) # Argument 3 is the amount of output rows
# Out:
#                    A         B         C         D
# 2013-01-01  0.031456  0.606786  0.489153  0.608915
# 2013-01-02  0.437252  0.193781  0.698477  0.497230
# 2013-01-03  0.560852  0.689439  0.364026  0.950522

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-02  0.437252  0.193781  0.698477  0.497230
# 2013-01-03  0.560852  0.689439  0.364026  0.950522
# 2013-01-04  0.430390  0.752366  0.571990  0.086978
# 2013-01-05  0.369941  0.326520  0.587998  0.773797
# 2013-01-06  0.548520  0.519458  0.591992  0.354832

# %% [markdown]
# Display the `DataFrame.index` or `DataFrame.columns`:

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# Return a NumPy representation of the underlying data with `DataFrame.to_numpy()` without the index or column labels:

# %%
df.to_numpy()
# Out:
# array([[0.03145569, 0.60678625, 0.4891535 , 0.60891543],
#        [0.43725203, 0.19378103, 0.69847672, 0.49722966],
#        [0.56085179, 0.68943897, 0.36402606, 0.95052216],
#        [0.43039028, 0.75236567, 0.57198954, 0.08697836],
#        [0.36994131, 0.32652034, 0.58799848, 0.77379692],
#        [0.54852039, 0.51945754, 0.59199212, 0.35483154]])

# %% [markdown]
# `describe()` shows a quick statistic summary of your data:

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.396402  0.514725  0.550606  0.545379
# std    0.193336  0.216297  0.113157  0.306304
# min    0.031456  0.193781  0.364026  0.086978
# 25%    0.385054  0.374755  0.509863  0.390431
# 50%    0.433821  0.563122  0.579994  0.553073
# 75%    0.520703  0.668776  0.590994  0.732577
# max    0.560852  0.752366  0.698477  0.950522

# %% [markdown]
# Transposing your data:

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.031456    0.437252    0.560852    0.430390    0.369941    0.548520
# B    0.606786    0.193781    0.689439    0.752366    0.326520    0.519458
# C    0.489153    0.698477    0.364026    0.571990    0.587998    0.591992
# D    0.608915    0.497230    0.950522    0.086978    0.773797    0.354832

# %% [markdown]
# `DataFrame.sort_index()` sorts by an axis:

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.608915  0.489153  0.606786  0.031456
# 2013-01-02  0.497230  0.698477  0.193781  0.437252
# 2013-01-03  0.950522  0.364026  0.689439  0.560852
# 2013-01-04  0.086978  0.571990  0.752366  0.430390
# 2013-01-05  0.773797  0.587998  0.326520  0.369941
# 2013-01-06  0.354832  0.591992  0.519458  0.548520

# %% [markdown]
# `DataFrame.sort_values()` sorts by values:

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-02  0.437252  0.193781  0.698477  0.497230
# 2013-01-05  0.369941  0.326520  0.587998  0.773797
# 2013-01-06  0.548520  0.519458  0.591992  0.354832
# 2013-01-01  0.031456  0.606786  0.489153  0.608915
# 2013-01-03  0.560852  0.689439  0.364026  0.950522
# 2013-01-04  0.430390  0.752366  0.571990  0.086978
